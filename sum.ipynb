# %% [markdown]
# ##DAY 3 ASSIGNMENT-1
#        SUM OF n NUMBERS USING WHILE LOOP

# %%
sum1=0
while True:
  num1=int(input("enter the number"))
  sum1=sum1+num1
  print (sum1)
  if num1==0:
    break
  print ("total sum is",sum1)
# Out:
# enter the number3
# 3
# total sum is 3
# enter the number7
# 10
# total sum is 10
# enter the number9
# 19
# total sum is 19
# enter the number23
# 42
# total sum is 42
# enter the number5
# 47
# total sum is 47
# enter the number0
# 47
